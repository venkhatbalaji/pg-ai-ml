# %% [markdown]
# # Problem Statement:
#
# This data set includes customers who have paid off their loans, who have been past due and put into collection without paying back their loan and interests, and who have paid off only after they were put in the collection. The financial product is a bullet loan that customers should pay off all of their loan debt in just one time by the end of the term, instead of an installment schedule. Of course, they could pay off earlier than their pay schedule.
#
# ### Attribute information:
#
# - Loan_status: Whether a loan is paid off, in the collection, new customer yet to pay off, or paid off after the collection efforts
#
# - Principal: Basic principal loan amount at the origination
#
# - terms: Can be weekly (7 days), biweekly, and monthly payoff schedule
#
# - Age, education, gender: A customer’s basic demographic information

# %% [markdown]
# ### Importing the required libraries

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np
# libaries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Library to encode the variables
from sklearn.preprocessing import OneHotEncoder
 # Library to split data
from sklearn.model_selection import train_test_split  
# library to import different optimizers
from tensorflow.keras import optimizers
# Library to import different loss functions 
from tensorflow.keras import losses
from tensorflow.keras.layers import Dense
# Library to avoid the warnings 
import warnings
warnings.filterwarnings('ignore')
# importing keras library
from tensorflow import keras
# library to convert the target variables to numpy arrays
from tensorflow.keras.utils import to_categorical
# library to plot classification report
from sklearn.metrics import classification_report

# %% [markdown]
# ### Q Import the dataset and answer the below question.
# ### Is the given problem statement a binary classification problem, and how many unique values are present in the target(loan_status) column?
# - Yes,2
# - No, 5
# - Yes,4
# - No, 3

# %%
data = pd.read_csv('Loan_payments_data.csv')

# %%
data.loan_status.nunique()
# Out:
# 3

# %% [markdown]
# ### Correct Answer:  No, 3
#
# **Explanation** Since the given problem statement has three classes to predict, this will be a Multi-class classification problem. If there are two classes to predict, it will be a binary classification problem.

# %% [markdown]
# ### Q Build a Neural Network model on the dataset and Obtain accuracy by following the below steps:
#
# - Store the Independent and Dependent features in X and y
# - Use train_test split to split the data (80% for training and 20% for testing)
# - Convert the target feature into a numpy array using Keras to_categorical function
#
# Use the below parameters mentioned.
# - Number of neurons in First and second layers are 64 and 32 respectively.
# - Use ReLu as an Activation function in Hidden layers and Adam as Optimizer with 1e-3 as learning rate
# - Built the model on 50 Epochs
#
#
# - **Note** - Do not use stratify sampling and Callbacks.
#
#
# - `>`80 and `<`90
# - `>`90 and `<`95
# - `>`95
# - `<`70

# %%
#Store the Independent and Dependent features in X and y
X = data.drop('loan_status',axis=1)
Y = data[['loan_status']]

# %%
# Use train_test split to split the data (80% for training and 20% for testing)
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
# Convert the target feature into a NumPy array using Keras to_categorical function
y_train = to_categorical(y_train, 3)
y_test_cat = to_categorical(y_test, 3)

# %%
# Model Building
#Defining the model
model = keras.Sequential()
# Adding the input layer with 64 neurons with relu as an activation function with input shape 11
model.add(Dense(64, activation='relu',input_shape=(11,))) 
# Adding the first hidden layer with 32 neurons with relu as an activation function
model.add(Dense(32, activation='relu'))
# Defining the output layer with 3 neurons with softmax as an activation function
model.add(Dense(3, activation='softmax'))
# Defining the Adam Optimizers
adam = optimizers.Adam(lr=1e-3)
# Compiling the model with categorical crossentropy as loss function with accuracy as metrics
model.compile(loss=losses.categorical_crossentropy, optimizer=adam, metrics=['accuracy']) 
# Fitting the model on X_train and y_train with 50 epcohs with 20% of validation split
history=model.fit(X_train, y_train, epochs=50,  validation_split=0.2,  verbose=2)
# Out:
# Epoch 1/50
# 10/10 - 1s - loss: 48.4591 - accuracy: 0.2156 - val_loss: 8.2859 - val_accuracy: 0.6000 - 558ms/epoch - 56ms/step
# Epoch 2/50
# 10/10 - 0s - loss:
ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 0.9795 - accuracy: 0.5844 - val_loss: 1.2619 - val_accuracy: 0.6000 - 31ms/epoch - 3ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 1.0226 - accuracy: 0.5875 - val_loss: 1.1895 - val_accuracy: 0.6000 - 27ms/epoch - 3ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 1.2815 - accuracy: 0.4750 - val_loss: 1.2781 - val_accuracy: 0.2250 - 28ms/epoch - 3ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 1.2024 - accuracy: 0.5281 - val_loss: 1.2493 - val_accuracy: 0.6000 - 29ms/epoch - 3ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 1.1314 - accuracy: 0.5500 - val_loss: 1.3168 - val_accuracy: 0.1125 - 23ms/epoch - 2ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 1.3718 - accuracy: 0.4375 - val_loss: 1.7804 - val_accuracy: 0.6125 - 29ms/epoch - 3ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 1.2855 - accuracy: 0.5031 - val_loss: 1.7009 - val_accuracy: 0.6000 - 27ms/epoch - 3ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 1.2254 - accuracy: 0.5344 - val_loss: 1.4058 - val_accuracy: 0.2250 - 27ms/epoch - 3ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 1.1985 - accuracy: 0.4875 - val_loss: 1.5001 - val_accuracy: 0.6125 - 28ms/epoch - 3ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 1.0523 - accuracy: 0.5875 - val_loss: 1.0050 - val_accuracy: 0.6000 - 34ms/epoch - 3ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 1.0131 - accuracy: 0.5750 - val_loss: 1.0456 - val_accuracy: 0.5625 - 22ms/epoch - 2ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 1.0223 - accuracy: 0.5500 - val_loss: 0.9981 - val_accuracy: 0.6000 - 35ms/epoch - 4ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 1.0252 - accuracy: 0.5188 - val_loss: 1.6036 - val_accuracy: 0.6125 - 33ms/epoch - 3ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 1.4897 - accuracy: 0.4938 - val_loss: 1.1760 - val_accuracy: 0.1875 - 33ms/epoch - 3ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 1.5050 - accuracy: 0.4531 - val_loss: 1.7114 - val_accuracy: 0.6125 - 34ms/epoch - 3ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 1.2911 - accuracy: 0.5406 - val_loss: 1.0789 - val_accuracy: 0.6125 - 31ms/epoch - 3ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 1.1377 - accuracy: 0.4969 - val_loss: 0.9829 - val_accuracy: 0.6000 - 25ms/epoch - 2ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 1.0887 - accuracy: 0.5594 - val_loss: 1.1515 - val_accuracy: 0.6125 - 27ms/epoch - 3ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 1.0380 - accuracy: 0.5813 - val_loss: 1.5983 - val_accuracy: 0.4250 - 30ms/epoch - 3ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 1.5305 - accuracy: 0.5094 - val_loss: 1.3845 - val_accuracy: 0.6125 - 34ms/epoch - 3ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 1.8196 - accuracy: 0.4500 - val_loss: 1.0947 - val_accuracy: 0.6125 - 33ms/epoch - 3ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 1.3068 - accuracy: 0.5562 - val_loss: 1.1515 - val_accuracy: 0.6125 - 23ms/epoch - 2ms/step

# %% [markdown]
# ### Correct Answer: **<70**

# %% [markdown]
# ### Q For the above model built, find the f1 - score for the 0th class using the classification report.
#
# - 0.51 - 0.55
# - 0.71 - 0.80
# - 0.60 - 0.70
# - 0.35 - 0.50

# %%
# Predicting on Test data 
y_pred=model.predict(X_test)

# %%
# Appling argmax function
y_pred_final=[]
for i in y_pred:
    y_pred_final.append(np.argmax(i))

# %%
# Classification report 
print(classification_report(y_test,y_pred_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        51
#            1       0.00      0.00      0.00        23
#            2       0.00      0.00      0.00        26
#
#     accuracy                           0.51       100
#    macro avg       0.17      0.33      0.23       100
# weighted avg       0.26      0.51      0.34       100

# %% [markdown]
# ### Correct Answer: 0.60 - 0.70

# %% [markdown]
# ### Q Build a model on the data using below hyperparameters and find the accuracy.
#
# - The number of neurons in First,second, thrid and fourth layers should be 128,64,64 and 32 respectively.
# - Use ReLu as an Activation function in Hidden layers and Adam as Optimizer with 1e-3 as learning rate
# - Built the model on 200 Epochs
#
# **Note** - Do not use stratify sampling and Callbacks.
#
# - `>`80 and `<`90
# - `>`90 and `<`95
# - `>`95
# - `<`75

# %%
# Model Building
#Defining the model
model_1 = keras.Sequential()
# Adding the input layer with 128 neurons with relu as an activation function input shape 11
model_1.add(Dense(128, activation='relu',kernel_initializer='he_uniform',input_shape=(11,))) 
# Adding the first hidden layer with 64 neurons with relu as an activation function
model_1.add(Dense(64, activation='relu',kernel_initializer='he_uniform'))
# Adding the second hidden layer with 64 neurons with relu as an activation function
model_1.add(Dense(64, activation='relu',kernel_initializer='he_uniform'))
# Adding the third hidden layer with 32 neurons with relu as an activation function
model_1.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))
# Defining the output layer with 3 neurons with softmax as an activation function
model_1.add(Dense(3, activation='softmax'))
# Defining the Adam Optimizers
adam = optimizers.Adam(lr=1e-3)
# Compiling the model with categorical crossentropy as loss function with accuracy as metrics
model_1.compile(loss=losses.categorical_crossentropy, optimizer=adam, metrics=['accuracy']) 
# Fitting the model on X_train and y_train with 200 epcohs having validation split of 20% 
history_1=model_1.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=128, verbose=2)
# Out:
# Epoch 1/200
# 3/3 - 0s - loss: 447.5361 - accuracy: 0.2031 - val_loss: 286.5123 - val_accuracy: 0.2375 - 363ms/epoch - 121ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 249.8191 - accuracy: 0.1719 - val_loss: 88.4429 - val_accuracy: 0.1500 - 26ms/epoch - 9ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 57.0634 - accuracy: 0.3063 - val_loss: 56.8718 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 57.0386 - accuracy: 0.6250 - val_loss: 86.3496 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 72.2492 - accuracy: 0.6250 - val_loss: 77.2203 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 56.9187 - accuracy: 0.6250 - val_loss: 39.6999 - val_accuracy: 0.6125 - 22ms/epoch - 7ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 24.4674 - accuracy: 0.5000 - val_loss: 28.4140 - val_accuracy: 0.1500 - 25ms/epoch - 8ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 24.3799 - accuracy: 0.1656 - val_loss: 10.3069 - val_accuracy: 0.2500 - 23ms/epoch - 8ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 12.0429 - accuracy: 0.4938 - val_loss: 28.0593 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 25.7534 - accuracy: 0.6250 - val_loss: 25.8275 - val_accuracy: 0.6125 - 33ms/epoch - 11ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 18.1117 - accuracy: 0.6250 - val_loss: 5.7530 - val_accuracy: 0.1500 - 29ms/epoch - 10ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 8.6784 - accuracy: 0.1750 - val_loss: 5.0050 - val_accuracy: 0.1500 - 26ms/epoch - 9ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 6.9625 - accuracy: 0.4406 - val_loss: 12.4108 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 9.7496 - accuracy: 0.6250 - val_loss: 4.6456 - val_accuracy: 0.3500 - 30ms/epoch - 10ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 3.7833 - accuracy: 0.3750 - val_loss: 5.7039 - val_accuracy: 0.1500 - 32ms/epoch - 11ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 4.5040 - accuracy: 0.4437 - val_loss: 2.4815 - val_accuracy: 0.1750 - 33ms/epoch - 11ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 3.5168 - accuracy: 0.3469 - val_loss: 4.8851 - val_accuracy: 0.6125 - 23ms/epoch - 8ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 4.4355 - accuracy: 0.6250 - val_loss: 4.5014 - val_accuracy: 0.1875 - 29ms/epoch - 10ms/step
# Epoch 19/200
# 3/3 - 0s - loss:
- val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 7.7863 - accuracy: 0.6250 - val_loss: 9.8874 - val_accuracy: 0.2375 - 21ms/epoch - 7ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 9.4814 - accuracy: 0.1937 - val_loss: 6.7029 - val_accuracy: 0.1500 - 23ms/epoch - 8ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 7.0233 - accuracy: 0.4656 - val_loss: 11.2304 - val_accuracy: 0.6125 - 26ms/epoch - 9ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 9.2634 - accuracy: 0.6250 - val_loss: 11.7783 - val_accuracy: 0.2500 - 23ms/epoch - 8ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 10.9984 - accuracy: 0.2469 - val_loss: 11.3552 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 9.6100 - accuracy: 0.6250 - val_loss: 17.6088 - val_accuracy: 0.1500 - 26ms/epoch - 9ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 13.3362 - accuracy: 0.2031 - val_loss: 9.4389 - val_accuracy: 0.6125 - 33ms/epoch - 11ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 7.5935 - accuracy: 0.6250 - val_loss: 9.6587 - val_accuracy: 0.2500 - 24ms/epoch - 8ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 9.9518 - accuracy: 0.2750 - val_loss: 13.4441 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 13.0315 - accuracy: 0.6250 - val_loss: 11.5663 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 7.7402 - accuracy: 0.5437 - val_loss: 9.1714 - val_accuracy: 0.1500 - 28ms/epoch - 9ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 9.1649 - accuracy: 0.1656 - val_loss: 7.0950 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 9.4337 - accuracy: 0.6250 - val_loss: 17.1836 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 12.1981 - accuracy: 0.6000 - val_loss: 14.5338 - val_accuracy: 0.1500 - 26ms/epoch - 9ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 9.0786 - accuracy: 0.2812 - val_loss: 5.5488 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 5.0087 - accuracy: 0.4375 - val_loss: 4.8072 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step

# %% [markdown]
# ### Correct Answer: <75

# %% [markdown]
# ### Q Build a model on the data using below hyperparameters and find the precision of 0th class using the classification report.
#
# * The number of neurons in First,and second layer should be 64 and 32 respectively.
# * Use ReLu as an Activation function in Hidden layers and SGD as Optimizer with 1e-3 as learning rate
# * Built the model on 100 Epochs
#
# **Note** - Do not use stratify sampling and Callbacks.

# %% [markdown]
# - `>`80 and `<`90
# - `>`60 and `<`70
# - `>`95
# - `<`60

# %%
# Model Building
#Defining the model
model_2 = keras.Sequential()
# Adding the input layer with 64 neurons with relu as an activation function of input shape 11
model_2.add(Dense(64, activation='relu',kernel_initializer='he_uniform',input_shape=(11,)))
# Adding the first hidden layer with 32 neurons with relu as an activation function
model_2.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))
# Defining the output layer with 3 neurons with softmax as an activation function
model_2.add(Dense(3, activation='softmax'))
# Deining the SGD optimizer
SGD = optimizers.SGD(lr=1e-3)
# Compiling the model with categorical crossentropy as loss function with accuracy as metrics
model_2.compile(loss=losses.categorical_crossentropy, optimizer=SGD, metrics=['accuracy']) 
# Fitting the model on X_train and y_train with 200 epcohs having validation split of 20% 
history_2=model_2.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=128, verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 0s - loss: 864.0719 - accuracy: 0.3688 - val_loss: 1.0983 - val_accuracy: 0.6125 - 281ms/epoch - 94ms/step
# Epoch 2/100
# 3/3 - 0s - loss: 1.0981 - accuracy: 0.6250 - val_loss: 1.0979 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 1.0978 - accuracy: 0.6250 - val_loss: 1.0975 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 1.0974 - accuracy: 0.6250 - val_loss: 1.0972 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 1.0970 - accuracy: 0.6250 - val_loss: 1.0968 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 1.0966 - accuracy: 0.6250 - val_loss: 1.0965 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 1.0962 - accuracy: 0.6250 - val_loss: 1.0961 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 1.0959 - accuracy: 0.6250 - val_loss: 1.0957 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 1.0955 - accuracy: 0.6250 - val_loss: 1.0954 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 1.0951 - accuracy: 0.6250 - val_loss: 1.0950 - val_accuracy: 0.6125 - 26ms/epoch - 9ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 1.0947 - accuracy: 0.6250 - val_loss: 1.0947 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 1.0943 - accuracy: 0.6250 - val_loss: 1.0943 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 1.0940 - accuracy: 0.6250 - val_loss: 1.0940 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 1.0936 - accuracy: 0.6250 - val_loss: 1.0936 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 1.0932 - accuracy: 0.6250 - val_loss: 1.0933 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 1.0929 - accuracy: 0.6250 - val_loss: 1.0929 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 1.0925 - accuracy: 0.6250 - val_loss: 1.0926 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 1.0921 - accuracy: 0.6250 - val_loss: 1.0922 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 1.0918 - accuracy: 0.6250 - val_loss: 1.0919 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 1.0914 - accuracy: 0.6250 - val_loss: 1.0915 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 1.0910 - accuracy: 0.6250 - val_loss: 1.0912 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 1.0906 - accuracy: 0.6250 - val_loss: 1.0908 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 1.0903 - accuracy: 0.6250 - val_loss: 1.0905 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 1.0899 - accuracy: 0.6250 - val_loss: 1.0901 - val_accuracy: 0.6125 - 28ms/epoch - 9ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 1.0895 - accuracy: 0.6250 - val_loss: 1.0898 - val_accuracy: 0.6125 - 18ms/epoch - 6ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 1.0892 - accuracy: 0.6250 - val_loss: 1.0895 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 1.0888 - accuracy: 0.6250 - val_loss: 1.0891 - val_accuracy: 0.6125 - 30ms/epoch - 10ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 1.0885 - accuracy: 0.6250 - val_loss: 1.0888 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 1.0881 - accuracy: 0.6250 - val_loss: 1.0885 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 1.0877 - accuracy: 0.6250 - val_loss: 1.0881 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 1.0874 - accuracy: 0.6250 - val_loss: 1.0878 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 1.0870 - accuracy: 0.6250 - val_loss: 1.0874 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 1.0866 - accuracy: 0.6250 - val_loss: 1.0871 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 1.0863 - accuracy: 0.6250 - val_loss: 1.0868 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 1.0859 - accuracy: 0.6250 - val_loss: 1.0864 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 1.0856 - accuracy: 0.6250 - val_loss: 1.0861 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 1.0852 - accuracy: 0.6250 - val_loss: 1.0857 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 1.0848 - accuracy: 0.6250 - val_loss: 1.0854 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 1.0845 - accuracy: 0.6250 - val_loss: 1.0851 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 1.0841 - accuracy: 0.6250 - val_loss: 1.0847 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 1.0838 - accuracy: 0.6250 - val_loss: 1.0844 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 1.0834 - accuracy: 0.6250 - val_loss: 1.0841 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 1.0831 - accuracy: 0.6250 - val_loss: 1.0837 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 1.0827 - accuracy: 0.6250 - val_loss: 1.0834 - val_accuracy: 0.6125 - 26ms/epoch - 9ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 1.0823 - accuracy: 0.6250 - val_loss: 1.0830 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 1.0820 - accuracy: 0.6250 - val_loss: 1.0827 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 1.0816 - accuracy: 0.6250 - val_loss: 1.0824 - val_accuracy: 0.6125 - 27ms/epoch - 9ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 1.0813 - accuracy: 0.6250 - val_loss: 1.0820 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 1.0809 - accuracy: 0.6250 - val_loss: 1.0817 - val_accuracy: 0.6125 - 29ms/epoch - 10ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 1.0806 - accuracy: 0.6250 - val_loss: 1.0814 - val_accuracy: 0.6125 - 20ms/epoch - 7ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 1.0802 - accuracy: 0.6250 - val_loss: 1.0811 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 1.0799 - accuracy: 0.6250 - val_loss: 1.0807 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 1.0795 - accuracy: 0.6250 - val_loss: 1.0804 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 1.0792 - accuracy: 0.6250 - val_loss: 1.0801 - val_accuracy: 0.6125 - 29ms/epoch - 10ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 1.0788 - accuracy: 0.6250 - val_loss: 1.0798 - val_accuracy: 0.6125 - 33ms/epoch - 11ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 1.0785 - accuracy: 0.6250 - val_loss: 1.0794 - val_accuracy: 0.6125 - 23ms/epoch - 8ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 1.0781 - accuracy: 0.6250 - val_loss: 1.0791 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 1.0778 - accuracy: 0.6250 - val_loss: 1.0788 - val_accuracy: 0.6125 - 28ms/epoch - 9ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 1.0775 - accuracy: 0.6250 - val_loss: 1.0785 - val_accuracy: 0.6125 - 28ms/epoch - 9ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 1.0771 - accuracy: 0.6250 - val_loss: 1.0782 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 1.0768 - accuracy: 0.6250 - val_loss: 1.0778 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 1.0765 - accuracy: 0.6250 - val_loss: 1.0775 - val_accuracy: 0.6125 - 33ms/epoch - 11ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 1.0761 - accuracy: 0.6250 - val_loss: 1.0772 - val_accuracy: 0.6125 - 28ms/epoch - 9ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 1.0758 - accuracy: 0.6250 - val_loss: 1.0769 - val_accuracy: 0.6125 - 23ms/epoch - 8ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 1.0754 - accuracy: 0.6250 - val_loss: 1.0765 - val_accuracy: 0.6125 - 23ms/epoch - 8ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 1.0751 - accuracy: 0.6250 - val_loss: 1.0762 - val_accuracy: 0.6125 - 27ms/epoch - 9ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 1.0747 - accuracy: 0.6250 - val_loss: 1.0759 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 1.0744 - accuracy: 0.6250 - val_loss: 1.0756 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 1.0741 - accuracy: 0.6250 - val_loss: 1.0753 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 1.0738 - accuracy: 0.6250 - val_loss: 1.0750 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 1.0734 - accuracy: 0.6250 - val_loss: 1.0747 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 1.0731 - accuracy: 0.6250 - val_loss: 1.0743 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 1.0727 - accuracy: 0.6250 - val_loss: 1.0740 - val_accuracy: 0.6125 - 21ms/epoch - 7ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 1.0724 - accuracy: 0.6250 - val_loss: 1.0737 - val_accuracy: 0.6125 - 21ms/epoch - 7ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 1.0721 - accuracy: 0.6250 - val_loss: 1.0734 - val_accuracy: 0.6125 - 27ms/epoch - 9ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 1.0717 - accuracy: 0.6250 - val_loss: 1.0731 - val_accuracy: 0.6125 - 47ms/epoch - 16ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 1.0714 - accuracy: 0.6250 - val_loss: 1.0728 - val_accuracy: 0.6125 - 26ms/epoch - 9ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 1.0711 - accuracy: 0.6250 - val_loss: 1.0725 - val_accuracy: 0.6125 - 18ms/epoch - 6ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 1.0707 - accuracy: 0.6250 - val_loss: 1.0721 - val_accuracy: 0.6125 - 14ms/epoch - 5ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 1.0704 - accuracy: 0.6250 - val_loss: 1.0719 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 1.0701 - accuracy: 0.6250 - val_loss: 1.0716 - val_accuracy: 0.6125 - 30ms/epoch - 10ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 1.0698 - accuracy: 0.6250 - val_loss: 1.0713 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 1.0694 - accuracy: 0.6250 - val_loss: 1.0709 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 1.0691 - accuracy: 0.6250 - val_loss: 1.0707 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 1.0688 - accuracy: 0.6250 - val_loss: 1.0704 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 1.0685 - accuracy: 0.6250 - val_loss: 1.0701 - val_accuracy: 0.6125 - 11ms/epoch - 4ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 1.0682 - accuracy: 0.6250 - val_loss: 1.0698 - val_accuracy: 0.6125 - 18ms/epoch - 6ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 1.0679 - accuracy: 0.6250 - val_loss: 1.0695 - val_accuracy: 0.6125 - 7ms/epoch - 2ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 1.0675 - accuracy: 0.6250 - val_loss: 1.0692 - val_accuracy: 0.6125 - 3ms/epoch - 1ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 1.0672 - accuracy: 0.6250 - val_loss: 1.0689 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 1.0669 - accuracy: 0.6250 - val_loss: 1.0686 - val_accuracy: 0.6125 - 26ms/epoch - 9ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 1.0666 - accuracy: 0.6250 - val_loss: 1.0682 - val_accuracy: 0.6125 - 20ms/epoch - 7ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 1.0662 - accuracy: 0.6250 - val_loss: 1.0679 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 1.0659 - accuracy: 0.6250 - val_loss: 1.0676 - val_accuracy: 0.6125 - 16ms/epoch - 5ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 1.0656 - accuracy: 0.6250 - val_loss: 1.0673 - val_accuracy: 0.6125 - 27ms/epoch - 9ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 1.0653 - accuracy: 0.6250 - val_loss: 1.0671 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 1.0650 - accuracy: 0.6250 - val_loss: 1.0668 - val_accuracy: 0.6125 - 8ms/epoch - 3ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 1.0647 - accuracy: 0.6250 - val_loss: 1.0665 - val_accuracy: 0.6125 - 19ms/epoch - 6ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 1.0643 - accuracy: 0.6250 - val_loss: 1.0662 - val_accuracy: 0.6125 - 24ms/epoch - 8ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 1.0640 - accuracy: 0.6250 - val_loss: 1.0659 - val_accuracy: 0.6125 - 25ms/epoch - 8ms/step

# %%
# Predicting on test data
y_pred_2=model_2.predict(X_test)

# %%
# Applying argmax
y_pred_final_2=[]
for i in y_pred_2:
    y_pred_final_2.append(np.argmax(i))

# %%
# Classification report
print(classification_report(y_test,y_pred_final_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        51
#            1       0.00      0.00      0.00        23
#            2       0.00      0.00      0.00        26
#
#     accuracy                           0.51       100
#    macro avg       0.17      0.33      0.23       100
# weighted avg       0.26      0.51      0.34       100

# %% [markdown]
# ### Correct Answer: **<60**
